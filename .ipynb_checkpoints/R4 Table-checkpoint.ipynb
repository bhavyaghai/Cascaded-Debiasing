# %%
from matplotlib import pyplot as plt
import numpy as np
import pandas
from IPython.display import display

# %%
adult_df = pandas.read_csv("./data/adult.csv", index_col=0)
compas_df = pandas.read_csv("./data/compas.csv", index_col=0)
bank_df = pandas.read_csv("./data/bank.csv", index_col=0)
german_df = pandas.read_csv("./data/german.csv", index_col=0)

for df in [adult_df, compas_df, bank_df, german_df]:
    df["FPR Diff"] = abs(df["False Positive Rate - Unprivileged"] - df["False Positive Rate - Privileged"])
    df["FNR Diff"] = abs(df["False Negative Rate - Unprivileged"] - df["False Negative Rate - Privileged"])
    df["Accuracy Diff"] = abs(df["Accuracy - Unprivileged"] - df["Accuracy - Privileged"])
    df["FOR Diff"] = abs(df["False Omission Rate - Unprivileged"] - df["False Omission Rate - Privileged"])
    df["FDR Diff"] = abs(df["False Discovery Rate - Unprivileged"] - df["False Discovery Rate - Privileged"])
    df["Statistical Parity Diff"] = abs(df["Unprivileged base Rate"] - df["Privileged base Rate"])
    df["F1 Score Diff"] = abs(df["F1 Score - Unprivileged"] - df["F1 Score - Privileged"])
    for metric in df.columns:
        if "Num" in metric or "rivileged" in metric:
            df.drop(metric, axis=1, inplace=True)
    df.set_index = df[df.columns[0]]

# %%
df = pandas.concat([adult_df, bank_df, german_df, compas_df])
df = df.abs()
df = df.groupby(df.index).mean()
df.head()
# Out:
#                   Accuracy  F1 Score  Theil Index  Consistency  FPR Diff  \
# CEOP              0.778617  0.452642     0.183067     0.916858  0.149583
# DIR               0.790142  0.592542     0.157233     0.903408  0.083542
# DIR + CEOP        0.776742  0.450925     0.184258     0.923800  0.118442
# DIR + EGR         0.785767  0.585900     0.160400     0.898667  0.060317
# DIR + EGR + CEOP  0.772817  0.453667     0.183900     0.916608  0.064042
#
#                   FNR Diff  Accuracy Diff  FOR Diff  FDR Diff  \
# CEOP              0.394517       0.063383  0.079850  0.146900
# DIR               0.075025       0.091800  0.128350  0.052458
# DIR + CEOP        0.354017       0.071875  0.092867  0.118067
# DIR + EGR         0.101242       0.104567  0.147817  0.075908
# DIR + EGR + CEOP  0.175108       0.096567  0.122433  0.076167
#
#                   Statistical Parity Diff  F1 Score Diff
# CEOP                             0.235717       0.404367
# DIR                              0.128625       0.053333
# DIR + CEOP                       0.196708       0.367967
# DIR + EGR                        0.087908       0.073558
# DIR + EGR + CEOP                 0.117842       0.194475

# %%
def num_interventions(name):
    if name == "Logistic Regression" or name  == "Meta Classifier":
        return 0
    if name.count('+') == 0:
        return 1
    if name.count('+') == 1:
        return 2
    if name.count('+') == 2:
        return 3
    
no_int = []
one_int = []
two_int = []
three_int = []
for row in list(adult_df.index):
    if num_interventions(row) == 0:
        no_int.append(row)
    elif num_interventions(row) == 1:
        one_int.append(row)
    elif num_interventions(row) == 2:
        two_int.append(row)
    elif num_interventions(row) == 3:
        three_int.append(row)
        
print(no_int)
print(one_int)
print(two_int)
print(three_int)

row_ordering = no_int + one_int + two_int + three_int
df = df.loc[row_ordering]
# Out:
# ['Logistic Regression']
# ['OP', 'DIR', 'EOP', 'CEOP', 'ROC', 'GFC', 'PR', 'EGR', 'GSR']
# ['OP + EOP', 'OP + CEOP', 'OP + ROC', 'OP + GFC', 'OP + PR', 'OP + EGR', 'OP + GSR', 'DIR + EOP', 'DIR + CEOP', 'DIR + ROC', 'DIR + GFC', 'DIR + PR', 'DIR + EGR', 'DIR + GSR', 'GFC + EOP', 'GFC + CEOP', 'GFC + ROC', 'PR + EOP', 'PR + CEOP', 'PR + ROC', 'EGR + EOP', 'EGR + CEOP', 'EGR + ROC', 'GSR + EOP', 'GSR + CEOP', 'GSR + ROC']
# ['OP + GFC + EOP', 'OP + GFC + CEOP', 'OP + GFC + ROC', 'OP + PR + EOP', 'OP + PR + CEOP', 'OP + PR + ROC', 'OP + EGR + EOP', 'OP + EGR + CEOP', 'OP + EGR + ROC', 'OP + GSR + EOP', 'OP + GSR + CEOP', 'OP + GSR + ROC', 'DIR + GFC + EOP', 'DIR + GFC + CEOP', 'DIR + GFC + ROC', 'DIR + PR + EOP', 'DIR + PR + CEOP', 'DIR + PR + ROC', 'DIR + EGR + EOP', 'DIR + EGR + CEOP', 'DIR + EGR + ROC', 'DIR + GSR + EOP', 'DIR + GSR + CEOP', 'DIR + GSR + ROC']

# %%
# save these results to file
# this file contains mean metric score for all interventions
df.to_csv("./results/R4_abs_mean_scores.csv")

# %%
df_ranked = {}
for metric in df.columns:
    if "Diff" in metric or metric in ["Theil Index"]:
        print("metric ascending: ", metric)
        df_ranked[metric] = df[metric].sort_values(ascending=True).index
    elif metric in ["Accuracy", "F1 Score", "Consistency"]:
        print("metric descending: ", metric)
        # accuracy, f1 score descending
        df_ranked[metric] = df[metric].sort_values(ascending=False).index
    else:
        print("Unaccounted metric: ", metric)
df_ranked = pandas.DataFrame(df_ranked)

# add rank column
df_ranked.insert(0, "Rank", range(1,61))
df_ranked
# Out:
# metric descending:  Accuracy
# metric descending:  F1 Score
# metric ascending:  Theil Index
# metric descending:  Consistency
# metric ascending:  FPR Diff
# metric ascending:  FNR Diff
# metric ascending:  Accuracy Diff
# metric ascending:  FOR Diff
# metric ascending:  FDR Diff
# metric ascending:  Statistical Parity Diff
# metric ascending:  F1 Score Diff
#     Rank             Accuracy             F1 Score          Theil Index  \
# 0      1  Logistic Regression  Logistic Regression       DIR + PR + ROC
# 1      2                  DIR                  DIR             OP + ROC
# 2      3            DIR + EGR            DIR + GSR             PR + ROC
# 3      4                  GSR                  GSR  Logistic Regression
# 4      5            DIR + GSR                  EGR                  EOP
# 5      6      DIR + EGR + ROC            DIR + EGR            DIR + ROC
# 6      7                  EGR             PR + EOP                  DIR
# 7      8      DIR + PR + CEOP      DIR + EGR + ROC             PR + EOP
# 8      9                 CEOP       OP + GSR + ROC            DIR + GSR
# 9     10            PR + CEOP                  EOP       DIR + PR + EOP
# 10    11           DIR + CEOP       DIR + PR + EOP                  GSR
# 11    12            EGR + ROC            GSR + ROC            DIR + EGR
# 12    13             PR + EOP             OP + ROC      DIR + EGR + ROC
# 13    14           GSR + CEOP            DIR + EOP            DIR + EOP
# 14    15     DIR + GSR + CEOP             PR + ROC            GSR + ROC
# 15    16     DIR + EGR + CEOP      DIR + EGR + EOP                  EGR
# 16    17       DIR + PR + EOP            GSR + EOP      DIR + GSR + ROC
# 17    18            EGR + EOP            EGR + EOP      DIR + GFC + EOP
# 18    19            GSR + EOP      DIR + GSR + ROC      DIR + EGR + EOP
# 19    20                  ROC       DIR + PR + ROC       OP + GSR + ROC
# 20    21           EGR + CEOP                  ROC            GSR + EOP
# 21    22            GSR + ROC      DIR + PR + CEOP      DIR + PR + CEOP
# 22    23      DIR + EGR + EOP        OP + PR + ROC            PR + CEOP
# 23    24            DIR + EOP            PR + CEOP      DIR + GSR + EOP
# 24    25      DIR + GSR + EOP            EGR + ROC            EGR + ROC
# 25    26                  EOP            DIR + ROC                  ROC
# 26    27             PR + ROC                   PR            EGR + EOP
# 27    28                   OP      DIR + GSR + EOP                 CEOP
# 28    29            OP + CEOP             OP + EOP     DIR + EGR + CEOP
# 29    30      OP + GSR + CEOP             DIR + PR           DIR + CEOP
# 30    31      OP + EGR + CEOP       OP + GSR + EOP     DIR + GSR + CEOP
# 31    32             OP + GSR      DIR + GFC + EOP                  GFC
# 32    33       OP + PR + CEOP           EGR + CEOP           GSR + CEOP
# 33    34       OP + EGR + ROC     DIR + EGR + CEOP           EGR + CEOP
# 34    35             OP + EGR                 CEOP            DIR + GFC
# 35    36             DIR + PR           DIR + CEOP        OP + PR + ROC
# 36    37                   PR       OP + GFC + EOP             OP + EOP
# 37    38      DIR + GSR + ROC           GSR + CEOP       OP + GSR + EOP
# 38    39            GFC + EOP     DIR + GSR + CEOP            GFC + EOP
# 39    40       OP + EGR + EOP       OP + EGR + EOP        OP + PR + EOP
# 40    41        OP + PR + EOP                  GFC       OP + GFC + EOP
# 41    42             OP + GFC                   OP            OP + CEOP
# 42    43                  GFC            DIR + GFC                   OP
# 43    44       OP + GFC + ROC            OP + CEOP       OP + EGR + EOP
# 44    45     DIR + GFC + CEOP        OP + PR + EOP      OP + GSR + CEOP
# 45    46      DIR + GFC + ROC             OP + GSR             OP + GSR
# 46    47      OP + GFC + CEOP            GFC + EOP       OP + PR + CEOP
# 47    48       OP + GSR + ROC             OP + EGR                   PR
# 48    49            GFC + ROC      OP + GSR + CEOP       OP + EGR + ROC
# 49    50      DIR + GFC + EOP       OP + PR + CEOP             OP + EGR
# 50    51             OP + EOP       OP + EGR + ROC             DIR + PR
# 51    52            DIR + GFC      OP + EGR + CEOP      DIR + GFC + ROC
# 52    53       OP + GSR + EOP            GFC + ROC      OP + EGR + CEOP
# 53    54        OP + PR + ROC      DIR + GFC + ROC      OP + GFC + CEOP
# 54    55           GFC + CEOP      OP + GFC + CEOP       OP + GFC + ROC
# 55    56            DIR + ROC       OP + GFC + ROC     DIR + GFC + CEOP
# 56    57       OP + GFC + EOP           GFC + CEOP            GFC + ROC
# 57    58              OP + PR              OP + PR           GFC + CEOP
# 58    59             OP + ROC     DIR + GFC + CEOP              OP + PR
# 59    60       DIR + PR + ROC             OP + GFC             OP + GFC
#
#             Consistency             FPR Diff             FNR Diff  \
# 0        OP + GFC + ROC       OP + GFC + ROC       OP + EGR + EOP
# 1       OP + GFC + CEOP            GFC + EOP       OP + GFC + ROC
# 2              OP + GFC            DIR + EOP             PR + EOP
# 3                    OP             OP + GFC        OP + PR + EOP
# 4              OP + GSR      DIR + GSR + EOP             OP + GFC
# 5        OP + EGR + ROC        OP + PR + EOP            EGR + EOP
# 6               OP + PR      DIR + EGR + EOP             OP + ROC
# 7       OP + GSR + CEOP       OP + EGR + EOP            GFC + EOP
# 8        OP + PR + CEOP            GSR + EOP                  GFC
# 9             OP + CEOP                  EOP            GSR + EOP
# 10             OP + ROC             OP + EGR      DIR + GSR + EOP
# 11       OP + GSR + ROC        OP + PR + ROC             OP + EOP
# 12             OP + EGR            DIR + GFC       OP + GSR + ROC
# 13      OP + EGR + CEOP       DIR + PR + EOP            DIR + GFC
# 14            DIR + GFC             OP + EOP            GFC + ROC
# 15        OP + PR + ROC            EGR + EOP                  EOP
# 16     DIR + GFC + CEOP      OP + GFC + CEOP            DIR + EOP
# 17                  GFC       OP + GSR + EOP       OP + EGR + ROC
# 18      DIR + GFC + ROC            EGR + ROC       OP + GSR + EOP
# 19           GFC + CEOP             PR + EOP        OP + PR + ROC
# 20            GFC + ROC                  EGR             OP + EGR
# 21           DIR + CEOP       OP + EGR + ROC             DIR + PR
# 22     DIR + GSR + CEOP             OP + ROC            DIR + ROC
# 23                 CEOP                  GFC                   PR
# 24     DIR + EGR + CEOP     DIR + GFC + CEOP      DIR + EGR + EOP
# 25           GSR + CEOP      DIR + GFC + EOP       OP + GFC + EOP
# 26           EGR + CEOP             PR + ROC              OP + PR
# 27                  ROC            GSR + ROC                  DIR
# 28                  DIR       OP + GFC + EOP       OP + PR + CEOP
# 29      DIR + EGR + ROC            GFC + ROC  Logistic Regression
# 30            DIR + GSR      DIR + EGR + ROC      DIR + GFC + EOP
# 31            DIR + EGR                  ROC                  ROC
# 32      DIR + PR + CEOP       OP + GSR + ROC       DIR + PR + EOP
# 33             PR + ROC            DIR + EGR             PR + ROC
# 34            DIR + ROC                  GSR      OP + GSR + CEOP
# 35            EGR + ROC     DIR + EGR + CEOP             OP + GSR
# 36             DIR + PR      OP + EGR + CEOP      DIR + GSR + ROC
# 37  Logistic Regression             OP + GSR       DIR + PR + ROC
# 38                  GSR           EGR + CEOP            DIR + EGR
# 39      DIR + GSR + ROC      DIR + GSR + ROC            GSR + ROC
# 40            PR + CEOP            DIR + GSR      OP + GFC + CEOP
# 41                   PR           GFC + CEOP                   OP
# 42                  EGR                   OP                  GSR
# 43            GSR + ROC              OP + PR            EGR + ROC
# 44       OP + EGR + EOP       DIR + PR + ROC      DIR + EGR + ROC
# 45            GFC + EOP            DIR + ROC      DIR + GFC + ROC
# 46            GSR + EOP           GSR + CEOP            OP + CEOP
# 47       DIR + PR + EOP                  DIR      OP + EGR + CEOP
# 48            EGR + EOP      OP + GSR + CEOP                  EGR
# 49       DIR + PR + ROC             DIR + PR            DIR + GSR
# 50      DIR + GSR + EOP       OP + PR + CEOP           GFC + CEOP
# 51             PR + EOP     DIR + GSR + CEOP     DIR + EGR + CEOP
# 52      DIR + GFC + EOP            OP + CEOP     DIR + GFC + CEOP
# 53        OP + PR + EOP                   PR           GSR + CEOP
# 54      DIR + EGR + EOP      DIR + PR + CEOP           EGR + CEOP
# 55            DIR + EOP  Logistic Regression            PR + CEOP
# 56                  EOP           DIR + CEOP     DIR + GSR + CEOP
# 57             OP + EOP            PR + CEOP      DIR + PR + CEOP
# 58       OP + GSR + EOP      DIR + GFC + ROC           DIR + CEOP
# 59       OP + GFC + EOP                 CEOP                 CEOP
#
#           Accuracy Diff             FOR Diff             FDR Diff  \
# 0             DIR + GFC      DIR + GFC + ROC  Logistic Regression
# 1       DIR + GFC + ROC                 CEOP                  DIR
# 2            GFC + CEOP           GFC + CEOP                  GFC
# 3        OP + GSR + ROC           DIR + CEOP      DIR + EGR + ROC
# 4              PR + ROC            DIR + GFC            DIR + EGR
# 5         OP + PR + ROC     DIR + GSR + CEOP     DIR + EGR + CEOP
# 6                   GFC             OP + ROC           GSR + CEOP
# 7                   EOP      DIR + PR + CEOP                   PR
# 8       DIR + GFC + EOP            PR + CEOP           GFC + CEOP
# 9             GFC + ROC            GFC + ROC             DIR + PR
# 10                 CEOP           GSR + CEOP            PR + CEOP
# 11            GFC + EOP                  GFC           EGR + CEOP
# 12           GSR + CEOP                   PR            GFC + ROC
# 13             OP + EOP             DIR + PR           DIR + CEOP
# 14           DIR + CEOP     DIR + GFC + CEOP            DIR + GSR
# 15     DIR + GFC + CEOP  Logistic Regression      OP + GSR + CEOP
# 16            GSR + EOP     DIR + EGR + CEOP            DIR + GFC
# 17             PR + EOP                  DIR            EGR + ROC
# 18     DIR + GSR + CEOP            DIR + ROC      DIR + PR + CEOP
# 19       OP + GSR + EOP           EGR + CEOP            GFC + EOP
# 20            GSR + ROC      DIR + GSR + EOP       OP + GFC + ROC
# 21            PR + CEOP      DIR + GSR + ROC                  ROC
# 22            DIR + EOP                  EOP             OP + GFC
# 23            EGR + EOP             PR + EOP            GSR + ROC
# 24           EGR + CEOP            DIR + EOP       DIR + PR + EOP
# 25                  GSR       DIR + PR + ROC            DIR + ROC
# 26      DIR + PR + CEOP            EGR + EOP                  GSR
# 27      DIR + GSR + EOP      DIR + EGR + EOP      DIR + GFC + ROC
# 28                  ROC            GSR + EOP                  EGR
# 29       DIR + PR + ROC      OP + GFC + CEOP                 CEOP
# 30  Logistic Regression                  ROC      DIR + GSR + ROC
# 31      DIR + EGR + EOP            DIR + GSR             PR + ROC
# 32       DIR + PR + EOP            DIR + EGR     DIR + GSR + CEOP
# 33                   PR            GFC + EOP                   OP
# 34             DIR + PR       OP + GSR + ROC      OP + GFC + CEOP
# 35      DIR + GSR + ROC                  GSR             PR + EOP
# 36                  EGR        OP + PR + ROC        OP + PR + EOP
# 37                  DIR             PR + ROC            EGR + EOP
# 38     DIR + EGR + CEOP       DIR + PR + EOP              OP + PR
# 39            EGR + ROC       OP + GFC + ROC                  EOP
# 40       OP + GFC + EOP              OP + PR     DIR + GFC + CEOP
# 41       OP + EGR + EOP      DIR + EGR + ROC            GSR + EOP
# 42            DIR + GSR      DIR + GFC + EOP       DIR + PR + ROC
# 43            DIR + EGR            GSR + ROC        OP + PR + ROC
# 44             OP + ROC            OP + CEOP            DIR + EOP
# 45      DIR + EGR + ROC                   OP       OP + GSR + EOP
# 46                   OP            EGR + ROC      DIR + EGR + EOP
# 47            OP + CEOP                  EGR            OP + CEOP
# 48        OP + PR + EOP       OP + PR + CEOP       OP + GFC + EOP
# 49            DIR + ROC      OP + EGR + CEOP             OP + EOP
# 50             OP + EGR      OP + GSR + CEOP       OP + EGR + ROC
# 51       OP + EGR + ROC             OP + GFC       OP + GSR + ROC
# 52              OP + PR             OP + GSR             OP + ROC
# 53       OP + PR + CEOP       OP + EGR + EOP       OP + EGR + EOP
# 54             OP + GSR       OP + EGR + ROC      DIR + GSR + EOP
# 55      OP + GSR + CEOP        OP + PR + EOP      OP + EGR + CEOP
# 56      OP + EGR + CEOP             OP + EGR      DIR + GFC + EOP
# 57       OP + GFC + ROC             OP + EOP             OP + EGR
# 58             OP + GFC       OP + GFC + EOP       OP + PR + CEOP
# 59      OP + GFC + CEOP       OP + GSR + EOP             OP + GSR
#
#    Statistical Parity Diff        F1 Score Diff
# 0                 OP + EGR            EGR + ROC
# 1            OP + PR + ROC                  GSR
# 2           OP + GFC + EOP            GSR + ROC
# 3           OP + GFC + ROC                  EGR
# 4           OP + EGR + ROC                   PR
# 5                 OP + EOP             OP + EGR
# 6            OP + PR + EOP             DIR + PR
# 7                DIR + GFC       OP + EGR + ROC
# 8           OP + GSR + EOP      DIR + GFC + EOP
# 9                 OP + GFC                  DIR
# 10               EGR + ROC             OP + GFC
# 11                OP + ROC            GFC + ROC
# 12               GFC + EOP        OP + PR + EOP
# 13          OP + EGR + EOP  Logistic Regression
# 14                     EGR            EGR + EOP
# 15         DIR + EGR + EOP             PR + EOP
# 16         DIR + GFC + EOP            GFC + EOP
# 17         DIR + GSR + EOP       OP + GSR + EOP
# 18               DIR + EOP      DIR + GSR + EOP
# 19               GSR + ROC       OP + GFC + ROC
# 20          DIR + PR + EOP            DIR + EOP
# 21         DIR + GSR + ROC            GSR + EOP
# 22                     GFC              OP + PR
# 23         OP + GFC + CEOP       OP + GFC + EOP
# 24                     ROC      DIR + EGR + EOP
# 25               GFC + ROC            DIR + EGR
# 26                PR + ROC       OP + EGR + EOP
# 27               GSR + EOP             OP + EOP
# 28          DIR + PR + ROC                  EOP
# 29          OP + GSR + ROC                  GFC
# 30               DIR + ROC                  ROC
# 31                     GSR       DIR + PR + EOP
# 32                     EOP      DIR + EGR + ROC
# 33               EGR + EOP      OP + GSR + CEOP
# 34         DIR + EGR + ROC       OP + PR + CEOP
# 35                PR + EOP      DIR + GSR + ROC
# 36        DIR + GFC + CEOP            DIR + GFC
# 37               DIR + EGR            DIR + ROC
# 38                OP + GSR             PR + ROC
# 39                 OP + PR            DIR + GSR
# 40         OP + EGR + CEOP        OP + PR + ROC
# 41         OP + GSR + CEOP             OP + GSR
# 42              GFC + CEOP       DIR + PR + ROC
# 43          OP + PR + CEOP                   OP
# 44                      OP            OP + CEOP
# 45               DIR + GSR      OP + GFC + CEOP
# 46                DIR + PR       OP + GSR + ROC
# 47        DIR + EGR + CEOP      OP + EGR + CEOP
# 48              EGR + CEOP      DIR + GFC + ROC
# 49                     DIR     DIR + EGR + CEOP
# 50               OP + CEOP             OP + ROC
# 51         DIR + GFC + ROC     DIR + GFC + CEOP
# 52                      PR           EGR + CEOP
# 53              GSR + CEOP           GFC + CEOP
# 54         DIR + PR + CEOP      DIR + PR + CEOP
# 55     Logistic Regression           GSR + CEOP
# 56        DIR + GSR + CEOP            PR + CEOP
# 57               PR + CEOP     DIR + GSR + CEOP
# 58              DIR + CEOP           DIR + CEOP
# 59                    CEOP                 CEOP

# %%
df_ranked.to_csv("./results/R4_mean_ranked.csv", index=False)

# %%
df["Statistical Parity Diff"].sort_values(ascending=True)[:10]
# Out:
# OP + EGR          0.015578
# OP + PR + ROC     0.016844
# OP + GFC + EOP    0.017856
# OP + GFC + ROC    0.019078
# OP + EGR + ROC    0.023522
# OP + EOP          0.026089
# OP + PR + EOP     0.026122
# DIR + GFC         0.027842
# OP + GSR + EOP    0.028122
# OP + GFC          0.029011
# Name: Statistical Parity Diff, dtype: float64

# %%
# trimmed version of df_ranked for the paper - top 10 and bottom 10
df_rank_trimmed = pandas.concat([df_ranked.head(10), df_ranked.tail(10)])
df_rank_trimmed
# Out:
#     Rank             Accuracy             F1 Score          Theil Index  \
# 0      1  Logistic Regression  Logistic Regression       DIR + PR + ROC
# 1      2                  DIR                  DIR             OP + ROC
# 2      3            DIR + EGR            DIR + GSR             PR + ROC
# 3      4                  GSR                  GSR  Logistic Regression
# 4      5            DIR + GSR                  EGR                  EOP
# 5      6      DIR + EGR + ROC            DIR + EGR            DIR + ROC
# 6      7                  EGR             PR + EOP                  DIR
# 7      8      DIR + PR + CEOP      DIR + EGR + ROC             PR + EOP
# 8      9                 CEOP       OP + GSR + ROC            DIR + GSR
# 9     10            PR + CEOP                  EOP       DIR + PR + EOP
# 50    51             OP + EOP       OP + EGR + ROC             DIR + PR
# 51    52            DIR + GFC      OP + EGR + CEOP      DIR + GFC + ROC
# 52    53       OP + GSR + EOP            GFC + ROC      OP + EGR + CEOP
# 53    54        OP + PR + ROC      DIR + GFC + ROC      OP + GFC + CEOP
# 54    55           GFC + CEOP      OP + GFC + CEOP       OP + GFC + ROC
# 55    56            DIR + ROC       OP + GFC + ROC     DIR + GFC + CEOP
# 56    57       OP + GFC + EOP           GFC + CEOP            GFC + ROC
# 57    58              OP + PR              OP + PR           GFC + CEOP
# 58    59             OP + ROC     DIR + GFC + CEOP              OP + PR
# 59    60       DIR + PR + ROC             OP + GFC             OP + GFC
#
#         Consistency             FPR Diff          FNR Diff    Accuracy Diff  \
# 0    OP + GFC + ROC       OP + GFC + ROC    OP + EGR + EOP        DIR + GFC
# 1   OP + GFC + CEOP            GFC + EOP    OP + GFC + ROC  DIR + GFC + ROC
# 2          OP + GFC            DIR + EOP          PR + EOP       GFC + CEOP
# 3                OP             OP + GFC     OP + PR + EOP   OP + GSR + ROC
# 4          OP + GSR      DIR + GSR + EOP          OP + GFC         PR + ROC
# 5    OP + EGR + ROC        OP + PR + EOP         EGR + EOP    OP + PR + ROC
# 6           OP + PR      DIR + EGR + EOP          OP + ROC              GFC
# 7   OP + GSR + CEOP       OP + EGR + EOP         GFC + EOP              EOP
# 8    OP + PR + CEOP            GSR + EOP               GFC  DIR + GFC + EOP
# 9         OP + CEOP                  EOP         GSR + EOP        GFC + ROC
# 50  DIR + GSR + EOP       OP + PR + CEOP        GFC + CEOP         OP + EGR
# 51         PR + EOP     DIR + GSR + CEOP  DIR + EGR + CEOP   OP + EGR + ROC
# 52  DIR + GFC + EOP            OP + CEOP  DIR + GFC + CEOP          OP + PR
# 53    OP + PR + EOP                   PR        GSR + CEOP   OP + PR + CEOP
# 54  DIR + EGR + EOP      DIR + PR + CEOP        EGR + CEOP         OP + GSR
# 55        DIR + EOP  Logistic Regression         PR + CEOP  OP + GSR + CEOP
# 56              EOP           DIR + CEOP  DIR + GSR + CEOP  OP + EGR + CEOP
# 57         OP + EOP            PR + CEOP   DIR + PR + CEOP   OP + GFC + ROC
# 58   OP + GSR + EOP      DIR + GFC + ROC        DIR + CEOP         OP + GFC
# 59   OP + GFC + EOP                 CEOP              CEOP  OP + GFC + CEOP
#
#             FOR Diff             FDR Diff Statistical Parity Diff  \
# 0    DIR + GFC + ROC  Logistic Regression                OP + EGR
# 1               CEOP                  DIR           OP + PR + ROC
# 2         GFC + CEOP                  GFC          OP + GFC + EOP
# 3         DIR + CEOP      DIR + EGR + ROC          OP + GFC + ROC
# 4          DIR + GFC            DIR + EGR          OP + EGR + ROC
# 5   DIR + GSR + CEOP     DIR + EGR + CEOP                OP + EOP
# 6           OP + ROC           GSR + CEOP           OP + PR + EOP
# 7    DIR + PR + CEOP                   PR               DIR + GFC
# 8          PR + CEOP           GFC + CEOP          OP + GSR + EOP
# 9          GFC + ROC             DIR + PR                OP + GFC
# 50   OP + GSR + CEOP       OP + EGR + ROC               OP + CEOP
# 51          OP + GFC       OP + GSR + ROC         DIR + GFC + ROC
# 52          OP + GSR             OP + ROC                      PR
# 53    OP + EGR + EOP       OP + EGR + EOP              GSR + CEOP
# 54    OP + EGR + ROC      DIR + GSR + EOP         DIR + PR + CEOP
# 55     OP + PR + EOP      OP + EGR + CEOP     Logistic Regression
# 56          OP + EGR      DIR + GFC + EOP        DIR + GSR + CEOP
# 57          OP + EOP             OP + EGR               PR + CEOP
# 58    OP + GFC + EOP       OP + PR + CEOP              DIR + CEOP
# 59    OP + GSR + EOP             OP + GSR                    CEOP
#
#        F1 Score Diff
# 0          EGR + ROC
# 1                GSR
# 2          GSR + ROC
# 3                EGR
# 4                 PR
# 5           OP + EGR
# 6           DIR + PR
# 7     OP + EGR + ROC
# 8    DIR + GFC + EOP
# 9                DIR
# 50          OP + ROC
# 51  DIR + GFC + CEOP
# 52        EGR + CEOP
# 53        GFC + CEOP
# 54   DIR + PR + CEOP
# 55        GSR + CEOP
# 56         PR + CEOP
# 57  DIR + GSR + CEOP
# 58        DIR + CEOP
# 59              CEOP

# %%
df_rank_trimmed.to_csv("./results/R4_rank_trimmed.csv", index=False)

# %% [markdown]
# <h3>Accuracy, F1 score for different number of interventions</h3>

# %%
df_int_type = {}
row_names = ["Zero", "One", "Two", "Three"]
for row_name, int_type in zip(row_names, [no_int, one_int, two_int, three_int]):
    df_int_type[row_name] = df.loc[int_type].mean()

df_int_type = pandas.DataFrame(df_int_type).T

df_int_type
# Out:
#        Accuracy  F1 Score  Theil Index  Consistency  FPR Diff  FNR Diff  \
# Zero   0.792525  0.612317     0.150908     0.892067  0.116767  0.078983
# One    0.749487  0.519192     0.186757     0.906528  0.070363  0.117077
# Two    0.713812  0.466142     0.209596     0.912054  0.055162  0.096424
# Three  0.695044  0.448374     0.212331     0.907958  0.052693  0.096261
#
#        Accuracy Diff  FOR Diff  FDR Diff  Statistical Parity Diff  \
# Zero        0.085975  0.121492  0.039583                 0.161250
# One         0.080536  0.135367  0.123200                 0.100566
# Two         0.086238  0.142687  0.150905                 0.080125
# Three       0.094597  0.155562  0.176943                 0.067685
#
#        F1 Score Diff
# Zero        0.059125
# One         0.105674
# Two         0.119918
# Three       0.125802

# %%
# code: https://www.pythoncharts.com/matplotlib/grouped-bar-charts-matplotlib/
labels = df_int_type.index
width = 0.35  # the width of the bars
x = np.arange(len(labels))

mean_acc = round(df_int_type["Accuracy"], 2)
mean_f1 = round(df_int_type["F1 Score"], 2)

fig, ax = plt.subplots(figsize=(9, 5))
plt.rcParams.update({'font.size': 14})
rects1 = ax.bar(x - width/2, mean_acc, label='Accuracy', color='steelblue', edgecolor='steelblue', alpha=0.8, width=0.32)
rects2 = ax.bar(x + width/2, mean_f1, label='F1 Score', color='lightgrey', edgecolor='darkgrey', alpha=0.8, width=0.32)

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Metric value')
ax.set_xlabel('Number of Interventions')
#ax.set_title('Mean Accuracy and F1 Score by number of Interventions')
ax.set_xticks(x, labels)
ax.set_ylim([0, 0.98])
ax.legend(loc=0)

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['bottom'].set_color('#DDDDDD')
ax.tick_params(bottom=False, left=False)
ax.set_axisbelow(True)
ax.yaxis.grid(True, color='#EEEEEE')
ax.xaxis.grid(False)

ax.bar_label(rects1, padding=3)
ax.bar_label(rects2, padding=3)

fig.tight_layout()
#plt.show()
fig.savefig('./figures/utility_by_intervention.png', dpi=600)

# %%
round(df_int_type["Accuracy"], 2)
# Out:
# No       0.79
# One      0.75
# Two      0.71
# Three    0.70
# Name: Accuracy, dtype: float64

# %% [markdown]
# <h3>EXTRA</h3>

# %%
adult_ranking = pandas.DataFrame(data=adult_df.index, columns=['Adult'])
for metric in adult_df.columns:
    if metric in ["Accuracy", "F1 Score"]:
        adult_ranking[metric] = adult_df[metric].rank(ascending=False, method="min").astype(int)
    else:
        adult_ranking[metric] = adult_df[metric].rank(ascending=True, method="min").astype(int)
adult_ranking = adult_ranking.set_index("Adult")
rank_scores = []
for intervention in adult_df["Adult"]:
    rank_scores.append(sum(adult_ranking.loc[intervention]))
adult_ranking["Rank Score"] = rank_scores
adult_ranking.sort_values("Rank Score", inplace=True)
adult_ranking
# Out:
#                      Accuracy  Theil Index  Consistency  F1 Score  \
# Adult
# RW                          1           17            1         2
# RW + ROC                   31            2            1         5
# DIR                         3           14            1         1
# Logistic Regression         1           17            1         2
# ROC                        31            2            1         5
# DIR + ROC                  33            1            1         4
# RW + PR + ROC              35            8            1         9
# RW + EGR + ROC              8           22            1        15
# DIR + PR + ROC             34            7            1         8
# PR + ROC                   35            8            1         9
# EOP                        23           30            1        29
# RW + EGR + EOP             20           38            1        38
# RW + EOP                   25           31            1        30
# DIR + EOP                  27           20            1        14
# EGR + ROC                   8           22            1        15
# RW + PR                    10           24            1        17
# EGR + EOP                  18           37            1        34
# DIR + EGR + ROC            13           19            1         7
# RW + GSR + ROC             46           10            1        31
# PR                         10           24            1        17
# RW + CEOP                   4           27            1        21
# RW + EGR                   16           32            1        27
# GSR + ROC                  46           10            1        31
# DIR + EGR + EOP            26           36            1        37
# DIR + PR                   12           27            1        26
# CEOP                        4           27            1        21
# DIR + GSR + ROC            48            4            1        33
# EGR                        16           32            1        27
# RW + PR + EOP              29           43            1        43
# DIR + EGR                  19           26            1        23
# DIR + CEOP                  6           21            1        11
# RW + GSR + EOP             45           47            1        47
# DIR + PR + EOP             28           45            1        45
# DIR + GSR + EOP            41           48            1        48
# DIR + EGR + CEOP            7           40            1        40
# PR + EOP                   30           44            1        44
# RW + GSR                   37           12            1        12
# RW + EGR + CEOP            15           41            1        41
# RW + PR + CEOP             21           34            1        35
# GSR                        37           12            1        12
# RW + GSR + CEOP            39           15            1        24
# EGR + CEOP                 14           41            1        41
# PR + CEOP                  21           34            1        35
# GSR + EOP                  44           46            1        46
# DIR + GSR                  42            5            1        19
# DIR + PR + CEOP            24           39            1        39
# GSR + CEOP                 39           15            1        24
# DIR + GSR + CEOP           43            6            1        20
#
#                      False Positive Rate Diff  False Negative Rate Diff  \
# Adult
# RW                                         31                        14
# RW + ROC                                   14                        22
# DIR                                        33                        13
# Logistic Regression                        31                        14
# ROC                                        14                        22
# DIR + ROC                                  16                        24
# RW + PR + ROC                              17                        20
# RW + EGR + ROC                             19                        28
# DIR + PR + ROC                             13                        19
# PR + ROC                                   17                        20
# EOP                                         1                         1
# RW + EGR + EOP                              3                         4
# RW + EOP                                    6                         7
# DIR + EOP                                  11                        10
# EGR + ROC                                  19                        28
# RW + PR                                    37                        26
# EGR + EOP                                   4                         8
# DIR + EGR + ROC                            28                        30
# RW + GSR + ROC                             24                        17
# PR                                         37                        26
# RW + CEOP                                  34                        40
# RW + EGR                                   22                        31
# GSR + ROC                                  24                        17
# DIR + EGR + EOP                             6                         9
# DIR + PR                                   36                        25
# CEOP                                       34                        40
# DIR + GSR + ROC                            29                        16
# EGR                                        22                        31
# RW + PR + EOP                               9                         2
# DIR + EGR                                  30                        33
# DIR + CEOP                                 42                        42
# RW + GSR + EOP                              5                         5
# DIR + PR + EOP                              8                         3
# DIR + GSR + EOP                             1                         6
# DIR + EGR + CEOP                           21                        34
# PR + EOP                                   10                        11
# RW + GSR                                   43                        43
# RW + EGR + CEOP                            26                        35
# RW + PR + CEOP                             40                        38
# GSR                                        43                        43
# RW + GSR + CEOP                            45                        45
# EGR + CEOP                                 27                        36
# PR + CEOP                                  40                        38
# GSR + EOP                                  12                        12
# DIR + GSR                                  47                        47
# DIR + PR + CEOP                            39                        37
# GSR + CEOP                                 45                        45
# DIR + GSR + CEOP                           48                        48
#
#                      Accuracy Diff  False Omission Rate Diff  \
# Adult
# RW                              36                        19
# RW + ROC                         1                        24
# DIR                             38                        16
# Logistic Regression             36                        19
# ROC                              1                        24
# DIR + ROC                        3                        23
# RW + PR + ROC                    4                        30
# RW + EGR + ROC                  15                        41
# DIR + PR + ROC                   6                        29
# PR + ROC                         4                        30
# EOP                             14                        33
# RW + EGR + EOP                  26                        35
# RW + EOP                        13                        32
# DIR + EOP                       10                        26
# EGR + ROC                       15                        41
# RW + PR                         39                        17
# EGR + EOP                       27                        36
# DIR + EGR + ROC                  9                        40
# RW + GSR + ROC                   7                        27
# PR                              39                        17
# RW + CEOP                       18                         8
# RW + EGR                        22                        44
# GSR + ROC                        7                        27
# DIR + EGR + EOP                 20                        34
# DIR + PR                        41                        21
# CEOP                            18                         8
# DIR + GSR + ROC                 11                        22
# EGR                             22                        44
# RW + PR + EOP                   29                        38
# DIR + EGR                       12                        46
# DIR + CEOP                      21                         7
# RW + GSR + EOP                  35                        47
# DIR + PR + EOP                  34                        39
# DIR + GSR + EOP                 42                        48
# DIR + EGR + CEOP                17                        15
# PR + EOP                        28                        37
# RW + GSR                        45                         3
# RW + EGR + CEOP                 24                        14
# RW + PR + CEOP                  30                        10
# GSR                             45                         3
# RW + GSR + CEOP                 43                         1
# EGR + CEOP                      25                        13
# PR + CEOP                       30                        10
# GSR + EOP                       33                        43
# DIR + GSR                       48                         5
# DIR + PR + CEOP                 32                        12
# GSR + CEOP                      43                         1
# DIR + GSR + CEOP                47                         6
#
#                      False Discovery Rate Diff  Statistical Parity Diff  \
# Adult
# RW                                           2                        1
# RW + ROC                                    14                        1
# DIR                                          1                       17
# Logistic Regression                          2                       17
# ROC                                         14                       17
# DIR + ROC                                   11                       17
# RW + PR + ROC                               17                        1
# RW + EGR + ROC                              22                        1
# DIR + PR + ROC                              16                       17
# PR + ROC                                    17                       17
# EOP                                         21                       17
# RW + EGR + EOP                              10                        1
# RW + EOP                                    25                        1
# DIR + EOP                                   31                       17
# EGR + ROC                                   22                       17
# RW + PR                                      4                        1
# EGR + EOP                                    7                       17
# DIR + EGR + ROC                             35                       17
# RW + GSR + ROC                              12                        1
# PR                                           4                       17
# RW + CEOP                                   19                        1
# RW + EGR                                    26                        1
# GSR + ROC                                   12                       17
# DIR + EGR + EOP                             28                       17
# DIR + PR                                     6                       17
# CEOP                                        19                       17
# DIR + GSR + ROC                             24                       17
# EGR                                         26                       17
# RW + PR + EOP                               30                        1
# DIR + EGR                                   39                       17
# DIR + CEOP                                  34                       17
# RW + GSR + EOP                               8                        1
# DIR + PR + EOP                              29                       17
# DIR + GSR + EOP                              9                       17
# DIR + EGR + CEOP                            40                       17
# PR + EOP                                    33                       17
# RW + GSR                                    42                        1
# RW + EGR + CEOP                             47                        1
# RW + PR + CEOP                              37                        1
# GSR                                         42                       17
# RW + GSR + CEOP                             44                        1
# EGR + CEOP                                  48                       17
# PR + CEOP                                   37                       17
# GSR + EOP                                   32                       17
# DIR + GSR                                   41                       17
# DIR + PR + CEOP                             36                       17
# GSR + CEOP                                  44                       17
# DIR + GSR + CEOP                            46                       17
#
#                      F1 Score Diff  Rank Score
# Adult
# RW                               9         133
# RW + ROC                        28         143
# DIR                              8         145
# Logistic Regression              9         149
# ROC                             28         159
# DIR + ROC                       30         163
# RW + PR + ROC                   25         167
# RW + EGR + ROC                   4         176
# DIR + PR + ROC                  27         177
# PR + ROC                        25         183
# EOP                             17         187
# RW + EGR + EOP                  14         190
# RW + EOP                        19         190
# DIR + EOP                       24         191
# EGR + ROC                        4         192
# RW + PR                         21         197
# EGR + EOP                       11         200
# DIR + EGR + ROC                  7         206
# RW + GSR + ROC                  31         207
# PR                              21         213
# RW + CEOP                       46         219
# RW + EGR                         1         223
# GSR + ROC                       31         223
# DIR + EGR + EOP                 18         232
# DIR + PR                        23         235
# CEOP                            46         235
# DIR + GSR + ROC                 33         238
# EGR                              1         239
# RW + PR + EOP                   15         240
# DIR + EGR                        3         249
# DIR + CEOP                      48         250
# RW + GSR + EOP                  12         253
# DIR + PR + EOP                  13         262
# DIR + GSR + EOP                  6         267
# DIR + EGR + CEOP                36         268
# PR + EOP                        16         271
# RW + GSR                        34         273
# RW + EGR + CEOP                 38         283
# RW + PR + CEOP                  41         288
# GSR                             34         289
# RW + GSR + CEOP                 43         301
# EGR + CEOP                      39         302
# PR + CEOP                       41         304
# GSR + EOP                       20         306
# DIR + GSR                       37         309
# DIR + PR + CEOP                 40         316
# GSR + CEOP                      43         317
# DIR + GSR + CEOP                45         327

# %%
compas_ranking = pandas.DataFrame(data=compas_df['Compas'], columns=['Compas'])
for metric in compas_df.columns:
    if metric == "Compas":
        continue
    if metric not in {"Accuracy", "F1 Score", "Consistency", "Theil Index"}:
        compas_ranking[metric] = compas_df[metric].rank(ascending=True, method="min").astype(int)
compas_ranking = compas_ranking.set_index("Compas")
rank_scores = []
for intervention in compas_df["Compas"]:
    rank_scores.append(sum(compas_ranking.loc[intervention]))
compas_ranking["Rank Score"] = rank_scores
compas_ranking.sort_values("Rank Score", inplace=True)
compas_ranking
# Out:
#                      False Positive Rate Diff  False Negative Rate Diff  \
# Compas
# RW + PR + ROC                              13                        11
# DIR + EGR + EOP                            11                         1
# DIR + ROC                                  15                        16
# RW + EGR + EOP                              1                        10
# RW + GSR + EOP                              3                         2
# RW + PR + EOP                               2                         8
# DIR + EOP                                  12                        14
# PR + ROC                                   13                        11
# RW + EGR                                   24                        19
# RW + EGR + CEOP                            29                        25
# EGR + EOP                                   5                         4
# RW + EOP                                    8                         5
# RW + PR + CEOP                             39                        37
# RW + CEOP                                  40                        38
# DIR + GSR + EOP                             3                         2
# RW + EGR + ROC                             22                        22
# EGR                                        24                        19
# PR + EOP                                    7                         9
# EGR + CEOP                                 30                        26
# DIR + EGR + ROC                            21                         6
# CEOP                                       42                        39
# RW                                         33                        33
# DIR + EGR + CEOP                           28                        27
# DIR                                        36                        35
# RW + ROC                                   19                        17
# DIR + CEOP                                 43                        41
# EOP                                         6                         7
# DIR + PR + ROC                             27                        11
# PR + CEOP                                  41                        40
# EGR + ROC                                  22                        22
# GSR + EOP                                  18                        21
# RW + PR                                    31                        31
# DIR + PR + CEOP                            37                        42
# DIR + EGR                                  26                        24
# DIR + PR                                   35                        36
# Logistic Regression                        33                        33
# ROC                                        19                        17
# DIR + PR + EOP                             16                        15
# PR                                         31                        31
# RW + GSR + ROC                              9                        29
# GSR + ROC                                   9                        29
# DIR + GSR + ROC                            17                        28
# DIR + GSR                                  38                        43
# RW + GSR                                   44                        44
# GSR                                        44                        44
# RW + GSR + CEOP                            46                        46
# GSR + CEOP                                 46                        46
# DIR + GSR + CEOP                           46                        46
#
#                      Accuracy Diff  False Omission Rate Diff  \
# Compas
# RW + PR + ROC                   14                        20
# DIR + EGR + EOP                 11                        33
# DIR + ROC                        6                        28
# RW + EGR + EOP                  31                        22
# RW + GSR + EOP                  37                        34
# RW + PR + EOP                   29                        29
# DIR + EOP                        9                        39
# PR + ROC                        14                        20
# RW + EGR                        17                        24
# RW + EGR + CEOP                  1                        32
# EGR + EOP                       26                        30
# RW + EOP                        34                        26
# RW + PR + CEOP                   3                        12
# RW + CEOP                        4                        10
# DIR + GSR + EOP                 37                        34
# RW + EGR + ROC                  17                        36
# EGR                             17                        24
# PR + EOP                        30                        23
# EGR + CEOP                       1                        31
# DIR + EGR + ROC                 24                        18
# CEOP                             4                         5
# RW                              22                         7
# DIR + EGR + CEOP                12                        13
# DIR                              8                        11
# RW + ROC                        27                        16
# DIR + CEOP                       7                         6
# EOP                             35                        27
# DIR + PR + ROC                  21                        19
# PR + CEOP                       10                         1
# EGR + ROC                       17                        36
# GSR + EOP                       42                        38
# RW + PR                         32                         3
# DIR + PR + CEOP                 16                         2
# DIR + EGR                       24                        14
# DIR + PR                        13                         9
# Logistic Regression             22                         7
# ROC                             27                        16
# DIR + PR + EOP                  36                        15
# PR                              32                         3
# RW + GSR + ROC                  44                        41
# GSR + ROC                       44                        41
# DIR + GSR + ROC                 43                        40
# DIR + GSR                       48                        43
# RW + GSR                        46                        44
# GSR                             46                        44
# RW + GSR + CEOP                 39                        46
# GSR + CEOP                      39                        46
# DIR + GSR + CEOP                39                        46
#
#                      False Discovery Rate Diff  Statistical Parity Diff  \
# Compas
# RW + PR + ROC                               37                        1
# DIR + EGR + EOP                             28                       17
# DIR + ROC                                   23                       17
# RW + EGR + EOP                              30                        1
# RW + GSR + EOP                              39                        1
# RW + PR + EOP                               31                        1
# DIR + EOP                                   26                       17
# PR + ROC                                    37                       17
# RW + EGR                                    24                        1
# RW + EGR + CEOP                             19                        1
# EGR + EOP                                   29                       17
# RW + EOP                                    32                        1
# RW + PR + CEOP                               6                        1
# RW + CEOP                                    5                        1
# DIR + GSR + EOP                             39                       17
# RW + EGR + ROC                              35                        1
# EGR                                         24                       17
# PR + EOP                                    33                       17
# EGR + CEOP                                  17                       17
# DIR + EGR + ROC                             41                       17
# CEOP                                         4                       17
# RW                                          15                        1
# DIR + EGR + CEOP                            20                       17
# DIR                                         10                       17
# RW + ROC                                    42                        1
# DIR + CEOP                                   2                       17
# EOP                                         34                       17
# DIR + PR + ROC                              45                       17
# PR + CEOP                                    9                       17
# EGR + ROC                                   35                       17
# GSR + EOP                                   18                       17
# RW + PR                                     21                        1
# DIR + PR + CEOP                              3                       17
# DIR + EGR                                   27                       17
# DIR + PR                                    13                       17
# Logistic Regression                         15                       17
# ROC                                         42                       17
# DIR + PR + EOP                              44                       17
# PR                                          21                       17
# RW + GSR + ROC                               7                        1
# GSR + ROC                                    7                       17
# DIR + GSR + ROC                             14                       17
# DIR + GSR                                    1                       17
# RW + GSR                                    11                        1
# GSR                                         11                       17
# RW + GSR + CEOP                             46                        1
# GSR + CEOP                                  46                       17
# DIR + GSR + CEOP                            46                       17
#
#                      F1 Score Diff  Rank Score
# Compas
# RW + PR + ROC                   10         106
# DIR + EGR + EOP                  7         108
# DIR + ROC                        8         113
# RW + EGR + EOP                  19         114
# RW + GSR + EOP                   2         118
# RW + PR + EOP                   18         118
# DIR + EOP                        4         121
# PR + ROC                        10         122
# RW + EGR                        13         122
# RW + EGR + CEOP                 16         123
# EGR + EOP                       12         123
# RW + EOP                        21         127
# RW + PR + CEOP                  29         127
# RW + CEOP                       30         128
# DIR + GSR + EOP                  2         134
# RW + EGR + ROC                   5         138
# EGR                             13         138
# PR + EOP                        20         139
# EGR + CEOP                      17         139
# DIR + EGR + ROC                 15         142
# CEOP                            32         143
# RW                              33         144
# DIR + EGR + CEOP                27         144
# DIR                             28         145
# RW + ROC                        23         145
# DIR + CEOP                      31         147
# EOP                             22         148
# DIR + PR + ROC                   9         149
# PR + CEOP                       36         154
# EGR + ROC                        5         154
# GSR + EOP                        1         155
# RW + PR                         37         156
# DIR + PR + CEOP                 40         157
# DIR + EGR                       26         158
# DIR + PR                        35         158
# Logistic Regression             33         160
# ROC                             23         161
# DIR + PR + EOP                  25         168
# PR                              37         172
# RW + GSR + ROC                  41         172
# GSR + ROC                       41         188
# DIR + GSR + ROC                 39         198
# DIR + GSR                       46         236
# RW + GSR                        47         237
# GSR                             47         253
# RW + GSR + CEOP                 43         267
# GSR + CEOP                      43         283
# DIR + GSR + CEOP                43         283

# %%
german_ranking = pandas.DataFrame(data=german_df['German'], columns=['German'])
for metric in german_df.columns:
    if metric == "German":
        continue
    if metric not in {"Accuracy", "F1 Score", "Consistency", "Theil Index"}:
        german_ranking[metric] = german_df[metric].rank(ascending=True, method="min").astype(int)
german_ranking = german_ranking.set_index("German")
rank_scores = []
for intervention in german_df["German"]:
    rank_scores.append(sum(german_ranking.loc[intervention]))
german_ranking["Rank Score"] = rank_scores
german_ranking.sort_values("Rank Score", inplace=True)
german_ranking
# Out:
#                      False Positive Rate Diff  False Negative Rate Diff  \
# German
# RW + GSR + EOP                              2                         1
# RW + EOP                                    9                         4
# RW + PR + EOP                               8                         9
# GSR + EOP                                   6                         3
# EOP                                         9                         4
# RW + EGR + EOP                              4                         7
# DIR + EOP                                  11                         6
# PR + EOP                                    5                        10
# RW + EGR + CEOP                             1                        21
# EGR + EOP                                   3                        12
# DIR + EGR + EOP                             7                         2
# DIR + EGR + CEOP                           20                        11
# EGR + CEOP                                 22                         8
# DIR + GSR + EOP                            21                        20
# RW + EGR + ROC                             18                        27
# DIR + EGR                                  16                        13
# DIR + PR + EOP                             17                        14
# DIR + EGR + ROC                            23                        19
# EGR + ROC                                  18                        27
# RW + EGR                                   27                        24
# RW + GSR + ROC                             33                        15
# RW + ROC                                   33                        15
# DIR + ROC                                  24                        22
# DIR + GSR + ROC                            24                        22
# DIR + GSR                                  31                        35
# DIR                                        31                        35
# EGR                                        27                        24
# RW                                         12                        31
# RW + GSR                                   12                        31
# GSR + ROC                                  33                        15
# ROC                                        33                        15
# Logistic Regression                        12                        31
# GSR                                        12                        31
# RW + CEOP                                  43                        40
# RW + GSR + CEOP                            43                        40
# DIR + CEOP                                 47                        40
# DIR + GSR + CEOP                           47                        40
# CEOP                                       43                        40
# GSR + CEOP                                 43                        40
# RW + PR                                    29                        37
# DIR + PR + ROC                             40                        26
# RW + PR + ROC                              41                        29
# PR                                         29                        37
# RW + PR + CEOP                             37                        46
# PR + ROC                                   41                        29
# DIR + PR                                   26                        39
# PR + CEOP                                  37                        46
# DIR + PR + CEOP                            39                        48
#
#                      Accuracy Diff  False Omission Rate Diff  \
# German
# RW + GSR + EOP                   2                        19
# RW + EOP                         4                        24
# RW + PR + EOP                   17                        23
# GSR + EOP                        3                        22
# EOP                              4                        24
# RW + EGR + EOP                  13                        20
# DIR + EOP                        7                        27
# PR + EOP                         1                        18
# RW + EGR + CEOP                 10                        37
# EGR + EOP                        8                        32
# DIR + EGR + EOP                 18                        17
# DIR + EGR + CEOP                12                        16
# EGR + CEOP                       6                        39
# DIR + GSR + EOP                 18                        31
# RW + EGR + ROC                  24                         5
# DIR + EGR                       11                        26
# DIR + PR + EOP                   9                        15
# DIR + EGR + ROC                 13                        21
# EGR + ROC                       24                         5
# RW + EGR                        13                        35
# RW + GSR + ROC                  32                         1
# RW + ROC                        32                         1
# DIR + ROC                       22                         9
# DIR + GSR + ROC                 22                         9
# DIR + GSR                       24                         7
# DIR                             24                         7
# EGR                             13                        35
# RW                              36                        11
# RW + GSR                        36                        11
# GSR + ROC                       32                         1
# ROC                             32                         1
# Logistic Regression             36                        11
# GSR                             36                        11
# RW + CEOP                       28                        42
# RW + GSR + CEOP                 28                        42
# DIR + CEOP                      20                        40
# DIR + GSR + CEOP                20                        40
# CEOP                            28                        42
# GSR + CEOP                      28                        42
# RW + PR                         44                        33
# DIR + PR + ROC                  40                        28
# RW + PR + ROC                   46                        29
# PR                              44                        33
# RW + PR + CEOP                  41                        47
# PR + ROC                        46                        29
# DIR + PR                        48                        38
# PR + CEOP                       41                        47
# DIR + PR + CEOP                 43                        46
#
#                      False Discovery Rate Diff  Statistical Parity Diff  \
# German
# RW + GSR + EOP                              23                        1
# RW + EOP                                    14                        1
# RW + PR + EOP                                8                        1
# GSR + EOP                                   17                       17
# EOP                                         14                       17
# RW + EGR + EOP                              21                        1
# DIR + EOP                                   11                       17
# PR + EOP                                    28                       17
# RW + EGR + CEOP                             18                        1
# EGR + EOP                                   16                       17
# DIR + EGR + EOP                             22                       17
# DIR + EGR + CEOP                            13                       17
# EGR + CEOP                                  12                       17
# DIR + GSR + EOP                              3                       17
# RW + EGR + ROC                              19                        1
# DIR + EGR                                   24                       17
# DIR + PR + EOP                              33                       17
# DIR + EGR + ROC                             25                       17
# EGR + ROC                                   19                       17
# RW + EGR                                    26                        1
# RW + GSR + ROC                              39                        1
# RW + ROC                                    39                        1
# DIR + ROC                                   34                       17
# DIR + GSR + ROC                             34                       17
# DIR + GSR                                    9                       17
# DIR                                          9                       17
# EGR                                         26                       17
# RW                                          29                        1
# RW + GSR                                    29                        1
# GSR + ROC                                   39                       17
# ROC                                         39                       17
# Logistic Regression                         29                       17
# GSR                                         29                       17
# RW + CEOP                                    4                        1
# RW + GSR + CEOP                              4                        1
# DIR + CEOP                                   1                       17
# DIR + GSR + CEOP                             1                       17
# CEOP                                         4                       17
# GSR + CEOP                                   4                       17
# RW + PR                                     43                        1
# DIR + PR + ROC                              45                       17
# RW + PR + ROC                               47                        1
# PR                                          43                       17
# RW + PR + CEOP                              36                        1
# PR + ROC                                    47                       17
# DIR + PR                                    46                       17
# PR + CEOP                                   36                       17
# DIR + PR + CEOP                             38                       17
#
#                      F1 Score Diff  Rank Score
# German
# RW + GSR + EOP                  12          60
# RW + EOP                         4          60
# RW + PR + EOP                    1          67
# GSR + EOP                        6          74
# EOP                              4          76
# RW + EGR + EOP                  15          81
# DIR + EOP                        2          81
# PR + EOP                        16          95
# RW + EGR + CEOP                  8          96
# EGR + EOP                        9          97
# DIR + EGR + EOP                 18         101
# DIR + EGR + CEOP                17         106
# EGR + CEOP                       7         111
# DIR + GSR + EOP                  3         113
# RW + EGR + ROC                  26         120
# DIR + EGR                       13         120
# DIR + PR + EOP                  19         124
# DIR + EGR + ROC                 14         132
# EGR + ROC                       26         136
# RW + EGR                        10         136
# RW + GSR + ROC                  22         143
# RW + ROC                        22         143
# DIR + ROC                       20         148
# DIR + GSR + ROC                 20         148
# DIR + GSR                       28         151
# DIR                             28         151
# EGR                             10         152
# RW                              32         152
# RW + GSR                        32         152
# GSR + ROC                       22         159
# ROC                             22         159
# Logistic Regression             32         168
# GSR                             32         168
# RW + CEOP                       36         194
# RW + GSR + CEOP                 36         194
# DIR + CEOP                      30         195
# DIR + GSR + CEOP                30         195
# CEOP                            36         210
# GSR + CEOP                      36         210
# RW + PR                         41         228
# DIR + PR + ROC                  40         236
# RW + PR + ROC                   45         238
# PR                              41         244
# RW + PR + CEOP                  43         251
# PR + ROC                        45         254
# DIR + PR                        48         262
# PR + CEOP                       43         267
# DIR + PR + CEOP                 47         278

# %%
bank_ranking = pandas.DataFrame(data=bank_df['Bank'], columns=['Bank'])
for metric in bank_df.columns:
    if metric == "Bank":
        continue
    if metric not in {"Accuracy", "F1 Score", "Consistency", "Theil Index"}:
        bank_ranking[metric] = bank_df[metric].rank(ascending=True, method="min").astype(int)
bank_ranking = bank_ranking.set_index("Bank")
rank_scores = []
for intervention in bank_df["Bank"]:
    rank_scores.append(sum(bank_ranking.loc[intervention]))
bank_ranking["Rank Score"] = rank_scores
bank_ranking.sort_values("Rank Score", inplace=True)
bank_ranking
# Out:
#                      False Positive Rate Diff  False Negative Rate Diff  \
# Bank
# RW + PR + EOP                               3                         3
# RW + GSR + EOP                              9                         1
# RW + EGR + EOP                             10                        13
# PR + EOP                                    3                         3
# RW + EOP                                   24                        15
# RW + PR + ROC                              21                         6
# RW + PR                                    43                        10
# GSR + EOP                                  13                         5
# RW + GSR + CEOP                            29                        43
# DIR + PR + EOP                             11                         2
# EOP                                        23                        14
# RW + GSR + ROC                             35                        36
# RW                                         41                        32
# PR + ROC                                   21                         6
# PR                                         43                        10
# DIR + GSR + CEOP                            1                        38
# RW + EGR + CEOP                            19                        39
# RW + ROC                                    5                        28
# GSR + CEOP                                 29                        43
# DIR + GSR + ROC                             8                        23
# DIR + PR + ROC                             12                        20
# GSR + ROC                                  35                        36
# DIR + CEOP                                 29                        42
# Logistic Regression                        41                        32
# RW + GSR                                   33                        21
# EGR + EOP                                  28                        18
# RW + EGR + ROC                             37                        24
# RW + EGR                                   37                        24
# DIR                                        16                        35
# DIR + ROC                                   7                        30
# DIR + PR                                   14                        19
# ROC                                         5                        28
# DIR + EOP                                  20                        12
# RW + CEOP                                  45                        47
# DIR + EGR + ROC                            17                        17
# GSR                                        33                        21
# EGR                                        37                        24
# EGR + CEOP                                 15                        41
# EGR + ROC                                  37                        24
# DIR + PR + CEOP                            29                        40
# DIR + EGR + CEOP                            1                        34
# DIR + GSR                                  26                         8
# CEOP                                       45                        47
# DIR + GSR + EOP                            26                        16
# DIR + EGR + EOP                            18                         9
# RW + PR + CEOP                             47                        45
# PR + CEOP                                  47                        45
# DIR + EGR                                  25                        31
#
#                      Accuracy Diff  False Omission Rate Diff  \
# Bank
# RW + PR + EOP                   13                        20
# RW + GSR + EOP                  27                        25
# RW + EGR + EOP                  30                        28
# PR + EOP                        13                        20
# RW + EOP                         5                        12
# RW + PR + ROC                   44                        44
# RW + PR                         36                        22
# GSR + EOP                       26                        24
# RW + GSR + CEOP                  8                         5
# DIR + PR + EOP                  43                        43
# EOP                              6                        13
# RW + GSR + ROC                   1                        15
# RW                              15                        10
# PR + ROC                        44                        44
# PR                              36                        22
# DIR + GSR + CEOP                29                        19
# RW + EGR + CEOP                 10                         9
# RW + ROC                        34                        29
# GSR + CEOP                       8                         5
# DIR + GSR + ROC                 32                        27
# DIR + PR + ROC                  33                        31
# GSR + ROC                        1                        15
# DIR + CEOP                      11                         7
# Logistic Regression             15                        10
# RW + GSR                        23                        32
# EGR + EOP                       12                        18
# RW + EGR + ROC                  17                        34
# RW + EGR                        17                        34
# DIR                             25                        17
# DIR + ROC                       31                        26
# DIR + PR                        40                        38
# ROC                             34                        29
# DIR + EOP                       41                        41
# RW + CEOP                        3                         1
# DIR + EGR + ROC                 39                        39
# GSR                             23                        32
# EGR                             17                        34
# EGR + CEOP                       7                         8
# EGR + ROC                       17                        34
# DIR + PR + CEOP                 28                        14
# DIR + EGR + CEOP                46                        46
# DIR + GSR                       42                        42
# CEOP                             3                         1
# DIR + GSR + EOP                 38                        40
# DIR + EGR + EOP                 47                        47
# RW + PR + CEOP                  21                         3
# PR + CEOP                       21                         3
# DIR + EGR                       48                        48
#
#                      False Discovery Rate Diff  Statistical Parity Diff  \
# Bank
# RW + PR + EOP                               32                        1
# RW + GSR + EOP                              22                        1
# RW + EGR + EOP                              18                        1
# PR + EOP                                    32                       17
# RW + EOP                                    37                        1
# RW + PR + ROC                                8                        1
# RW + PR                                      3                        1
# GSR + EOP                                   27                       17
# RW + GSR + CEOP                              5                        1
# DIR + PR + EOP                              14                       17
# EOP                                         36                       17
# RW + GSR + ROC                              29                        1
# RW                                          11                        1
# PR + ROC                                     8                       17
# PR                                           3                       17
# DIR + GSR + CEOP                             1                       17
# RW + EGR + CEOP                             28                        1
# RW + ROC                                    19                        1
# GSR + CEOP                                   5                       17
# DIR + GSR + ROC                             21                       17
# DIR + PR + ROC                              16                       17
# GSR + ROC                                   29                       17
# DIR + CEOP                                   7                       17
# Logistic Regression                         11                       17
# RW + GSR                                    38                        1
# EGR + EOP                                   40                       17
# RW + EGR + ROC                              44                        1
# RW + EGR                                    44                        1
# DIR                                         15                       17
# DIR + ROC                                   17                       17
# DIR + PR                                    13                       17
# ROC                                         19                       17
# DIR + EOP                                   23                       17
# RW + CEOP                                   25                        1
# DIR + EGR + ROC                             24                       17
# GSR                                         38                       17
# EGR                                         44                       17
# EGR + CEOP                                  48                       17
# EGR + ROC                                   44                       17
# DIR + PR + CEOP                             10                       17
# DIR + EGR + CEOP                             1                       17
# DIR + GSR                                   34                       17
# CEOP                                        25                       17
# DIR + GSR + EOP                             34                       17
# DIR + EGR + EOP                             41                       17
# RW + PR + CEOP                              42                        1
# PR + CEOP                                   42                       17
# DIR + EGR                                   31                       17
#
#                      F1 Score Diff  Rank Score
# Bank
# RW + PR + EOP                   25          97
# RW + GSR + EOP                  16         101
# RW + EGR + EOP                  10         110
# PR + EOP                        25         113
# RW + EOP                        29         123
# RW + PR + ROC                    1         125
# RW + PR                         11         126
# GSR + EOP                       19         131
# RW + GSR + CEOP                 43         134
# DIR + PR + EOP                   7         137
# EOP                             28         137
# RW + GSR + ROC                  20         137
# RW                              30         140
# PR + ROC                         1         141
# PR                              11         142
# DIR + GSR + CEOP                38         143
# RW + EGR + CEOP                 39         145
# RW + ROC                        33         149
# GSR + CEOP                      43         150
# DIR + GSR + ROC                 24         152
# DIR + PR + ROC                  23         152
# GSR + ROC                       20         153
# DIR + CEOP                      42         155
# Logistic Regression             30         156
# RW + GSR                         8         156
# EGR + EOP                       27         160
# RW + EGR + ROC                   3         160
# RW + EGR                         3         160
# DIR                             36         161
# DIR + ROC                       35         163
# DIR + PR                        22         163
# ROC                             33         165
# DIR + EOP                       15         169
# RW + CEOP                       47         169
# DIR + EGR + ROC                 18         171
# GSR                              8         172
# EGR                              3         176
# EGR + CEOP                      40         176
# EGR + ROC                        3         176
# DIR + PR + CEOP                 41         179
# DIR + EGR + CEOP                37         182
# DIR + GSR                       14         183
# CEOP                            47         185
# DIR + GSR + EOP                 17         188
# DIR + EGR + EOP                 13         192
# RW + PR + CEOP                  45         204
# PR + CEOP                       45         220
# DIR + EGR                       32         232
